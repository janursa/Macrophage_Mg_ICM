# %%
import os
from tools import dirs
from tools.tools import calibrate, edit_matlab_model
import json
# %load_ext autoreload
# %autoreload 2
# %config Completer.use_jedi = False
showOriginalModelString = True

# %%
target_package = 'P3'
###-------- import --------###
from models.params import free_params_p, fixed_params
from data.observations import observations
from models.models import Macrophage
### ----------------------###
edit_matlab_model(input_file=dirs.dir_matlab_model,output_file=dirs.dir_model)
free_params = free_params_p[target_package]
print(free_params)
model_obj = Macrophage(observations)

def callback(xk, convergence):
    params = {**fixed_params}
    keys = list(free_params.keys())
    for ii in range(len(keys)):
        params[keys[ii]] = xk[ii]
    error = model_obj.run(params = params)
    if  error < 0.01:
        return True
class Strategies:
    best1bin = 'best1bin'
    rand1exp = 'rand1exp'
inferred_params = calibrate(model = model_obj,fixed_params = fixed_params, free_params=free_params, n_proc=1,disp=True,max_iters=200,strategy=Strategies.best1bin,callback=callback)
with open(dirs.dir_calib_output,'w') as f:
    f.write(json.dumps(inferred_params))
os.system('say "Hey Matin, calibration is done, come back"')
# Out:
# {'k_ntrpm_p': [0, 1], 'n_ntrpm_p': [0, 30], 'k_ntrpm_t': [0, 1], 'n_ntrpm_t': [0, 10], 'k_trpm_s': [0, 1], 'k_m7ck_t1': [0, 1], 'k_m7ck_t2': [0, 1], 'n_m7ck_t': [0, 10], 'k_m7ck_deg': [0, 1]}
# differential_evolution step 1: f(x)= 0.399456
# differential_evolution step 2: f(x)= 0.399456
# differential_evolution step 3: f(x)= 0.36092
# differential_evolution step 4: f(x)= 0.36092
# differential_evolution step 5: f(x)= 0.36092
# differential_evolution step 6: f(x)= 0.36092
# differential_evolution step 7: f(x)= 0.36092
# differential_evolution step 8: f(x)= 0.336188
# differential_evolution step 9: f(x)= 0.336188
# differential_evolution step 10: f(x)= 0.333433
# differential_evolution step 11: f(x)= 0.333433
# differential_evolution step 12: f(x)= 0.333433
# differential_evolution step 13: f(x)= 0.323175
# differential_evolution step 14: f(x)= 0.323175
# differential_evolution step 15: f(x)= 0.323175
# differential_evolution step 16: f(x)= 0.323175
# differential_evolution step 17: f(x)= 0.276956
# differential_evolution step 18: f(x)= 0.276956
# differential_evolution step 19: f(x)= 0.261238
# differential_evolution step 20: f(x)= 0.261238
# differential_evolution step 21: f(x)= 0.261238
# differential_evolution step 22: f(x)= 0.261238
# differential_evolution step 23: f(x)= 0.261238
# differential_evolution step 24: f(x)= 0.261238
# differential_evolution step 25: f(x)= 0.261238
# differential_evolution step 26: f(x)= 0.261238
# differential_evolution step 27: f(x)= 0.261238
# differential_evolution step 28: f(x)= 0.261238
# differential_evolution step 29: f(x)= 0.261238
# differential_evolution step 30: f(x)= 0.261238
# differential_evolution step 31: f(x)= 0.261238
# differential_evolution step 32: f(x)= 0.261238
# differential_evolution step 33: f(x)= 0.261238
# differential_evolution step 34: f(x)= 0.261238
# differential_evolution step 35: f(x)= 0.261238
# differential_evolution step 36: f(x)= 0.261238
# differential_evolution step 37: f(x)= 0.261238
# differential_evolution step 38: f(x)= 0.261238
# differential_evolution step 39: f(x)= 0.261238
# differential_evolution step 40: f(x)= 0.261238
# differential_evolution step 41: f(x)= 0.261238
# differential_evolution step 42: f(x)= 0.261238
# differential_evolution step 43: f(x)= 0.261238
# differential_evolution step 44: f(x)= 0.261238
# differential_evolution step 45: f(x)= 0.261238
# differential_evolution step 46: f(x)= 0.261238
# differential_evolution step 47: f(x)= 0.261238
# differential_evolution step 48: f(x)= 0.256279
# differential_evolution step 49: f(x)= 0.256279
# differential_evolution step 50: f(x)= 0.256279
# differential_evolution step 51: f(x)= 0.256279
# differential_evolution step 52: f(x)= 0.256279
# differential_evolution step 53: f(x)= 0.256279
# differential_evolution step 54: f(x)= 0.256279
# differential_evolution step 55: f(x)= 0.256279
# differential_evolution step 56: f(x)= 0.256279
# differential_evolution step 57: f(x)= 0.256279
# differential_evolution step 58: f(x)= 0.256279
# differential_evolution step 59: f(x)= 0.256279
# differential_evolution step 60: f(x)= 0.256279
# differential_evolution step 61: f(x)= 0.256279
# differential_evolution step 62: f(x)= 0.256279
# differential_evolution step 63: f(x)= 0.256279
# differential_evolution step 64: f(x)= 0.256279
# differential_evolution step 65: f(x)= 0.256279
# differential_evolution step 66: f(x)= 0.255541
# differential_evolution step 67: f(x)= 0.255541
# differential_evolution step 68: f(x)= 0.255541
# differential_evolution step 69: f(x)= 0.255541
# differential_evolution step 70: f(x)= 0.255541
# differential_evolution step 71: f(x)= 0.254769
# differential_evolution step 72: f(x)= 0.254769
# differential_evolution step 73: f(x)= 0.254351
# differential_evolution step 74: f(x)= 0.253029
# differential_evolution step 75: f(x)= 0.252065
# differential_evolution step 76: f(x)= 0.252065
# differential_evolution step 77: f(x)= 0.250757
# differential_evolution step 78: f(x)= 0.250757
# differential_evolution step 79: f(x)= 0.249963
# differential_evolution step 80: f(x)= 0.249963
# differential_evolution step 81: f(x)= 0.249012
# differential_evolution step 82: f(x)= 0.249012
# differential_evolution step 83: f(x)= 0.24663
# differential_evolution step 84: f(x)= 0.24663
# differential_evolution step 85: f(x)= 0.24663
# differential_evolution step 86: f(x)= 0.24663
# differential_evolution step 87: f(x)= 0.24663
# differential_evolution step 88: f(x)= 0.24663
# differential_evolution step 89: f(x)= 0.24663
# differential_evolution step 90: f(x)= 0.24663
# differential_evolution step 91: f(x)= 0.24663
# differential_evolution step 92: f(x)= 0.24663
# differential_evolution step 93: f(x)= 0.24663
# differential_evolution step 94: f(x)= 0.24663
# differential_evolution step 95: f(x)= 0.24663
# differential_evolution step 96: f(x)= 0.24663
# differential_evolution step 97: f(x)= 0.24663
# differential_evolution step 98: f(x)= 0.24663
# differential_evolution step 99: f(x)= 0.24663
# differential_evolution step 100: f(x)= 0.24663
# differential_evolution step 101: f(x)= 0.24663
# differential_evolution step 102: f(x)= 0.24663
# differential_evolution step 103: f(x)= 0.24663
# differential_evolution step 104: f(x)= 0.24663
# differential_evolution step 105: f(x)= 0.24663
# differential_evolution step 106: f(x)= 0.24663
# differential_evolution step 107: f(x)= 0.24663
# differential_evolution step 108: f(x)= 0.24663
# differential_evolution step 109: f(x)= 0.24663
# differential_evolution step 110: f(x)= 0.24663
# differential_evolution step 111: f(x)= 0.24663
# differential_evolution step 112: f(x)= 0.24653
# differential_evolution step 113: f(x)= 0.24653
# differential_evolution step 114: f(x)= 0.246514
# differential_evolution step 115: f(x)= 0.246514
# differential_evolution step 116: f(x)= 0.246514
# differential_evolution step 117: f(x)= 0.246514
# differential_evolution step 118: f(x)= 0.246514
# differential_evolution step 119: f(x)= 0.246514
# differential_evolution step 120: f(x)= 0.246514
# differential_evolution step 121: f(x)= 0.246514
# differential_evolution step 122: f(x)= 0.245497
# differential_evolution step 123: f(x)= 0.245497
# differential_evolution step 124: f(x)= 0.245497
# differential_evolution step 125: f(x)= 0.245497
# differential_evolution step 126: f(x)= 0.245497
# differential_evolution step 127: f(x)= 0.245497
# differential_evolution step 128: f(x)= 0.245497
# differential_evolution step 129: f(x)= 0.245497
# differential_evolution step 130: f(x)= 0.245497
# differential_evolution step 131: f(x)= 0.244926
# differential_evolution step 132: f(x)= 0.244926
# differential_evolution step 133: f(x)= 0.244926
# differential_evolution step 134: f(x)= 0.244926
# differential_evolution step 135: f(x)= 0.244926
# differential_evolution step 136: f(x)= 0.244926
# differential_evolution step 137: f(x)= 0.244926
# differential_evolution step 138: f(x)= 0.244926
# differential_evolution step 139: f(x)= 0.244926
# differential_evolution step 140: f(x)= 0.244926
# differential_evolution step 141: f(x)= 0.244564
# differential_evolution step 142: f(x)= 0.244564
# differential_evolution step 143: f(x)= 0.244564
# differential_evolution step 144: f(x)= 0.244564
# differential_evolution step 145: f(x)= 0.244564
# differential_evolution step 146: f(x)= 0.244564
# differential_evolution step 147: f(x)= 0.244564
# differential_evolution step 148: f(x)= 0.244564
# differential_evolution step 149: f(x)= 0.244564
# differential_evolution step 150: f(x)= 0.244564
# differential_evolution step 151: f(x)= 0.244564
# differential_evolution step 152: f(x)= 0.244564
# differential_evolution step 153: f(x)= 0.244564
# differential_evolution step 154: f(x)= 0.244564
# differential_evolution step 155: f(x)= 0.244564
# differential_evolution step 156: f(x)= 0.244564
# differential_evolution step 157: f(x)= 0.244564
# differential_evolution step 158: f(x)= 0.244564
# differential_evolution step 159: f(x)= 0.244564
# differential_evolution step 160: f(x)= 0.24433
# differential_evolution step 161: f(x)= 0.24433
# differential_evolution step 162: f(x)= 0.24433
# differential_evolution step 163: f(x)= 0.24433
# differential_evolution step 164: f(x)= 0.24433
# differential_evolution step 165: f(x)= 0.24433
# differential_evolution step 166: f(x)= 0.24433
# differential_evolution step 167: f(x)= 0.244176
# differential_evolution step 168: f(x)= 0.244176
# differential_evolution step 169: f(x)= 0.244176
# differential_evolution step 170: f(x)= 0.244176
# differential_evolution step 171: f(x)= 0.244176
# differential_evolution step 172: f(x)= 0.244176
# differential_evolution step 173: f(x)= 0.244176
# differential_evolution step 174: f(x)= 0.244176
# differential_evolution step 175: f(x)= 0.244176
# differential_evolution step 176: f(x)= 0.244176
# differential_evolution step 177: f(x)= 0.244176
# differential_evolution step 178: f(x)= 0.244176
# differential_evolution step 179: f(x)= 0.244176
# differential_evolution step 180: f(x)= 0.244176
# differential_evolution step 181: f(x)= 0.244176
# differential_evolution step 182: f(x)= 0.243931
# differential_evolution step 183: f(x)= 0.243896
# differential_evolution step 184: f(x)= 0.243896
# differential_evolution step 185: f(x)= 0.243896
# differential_evolution step 186: f(x)= 0.243896
# differential_evolution step 187: f(x)= 0.243896
# differential_evolution step 188: f(x)= 0.243896
# differential_evolution step 189: f(x)= 0.243745
# differential_evolution step 190: f(x)= 0.243745
# differential_evolution step 191: f(x)= 0.243745
# differential_evolution step 192: f(x)= 0.243745
# differential_evolution step 193: f(x)= 0.243745
# differential_evolution step 194: f(x)= 0.243014
# differential_evolution step 195: f(x)= 0.243014
# differential_evolution step 196: f(x)= 0.243014
# differential_evolution step 197: f(x)= 0.243014
# differential_evolution step 198: f(x)= 0.243014
# differential_evolution step 199: f(x)= 0.243014
# differential_evolution step 200: f(x)= 0.243014
# 0

# %%
inferred_params_2_1 = inferred_params
print(inferred_params)
# Out:
# {'k_ntrpm_p': 0.10768912844244494, 'n_ntrpm_p': 12.22279370697598, 'k_ntrpm_t': 0.9606838875751695, 'n_ntrpm_t': 0.5160629614795429, 'k_trpm_s': 0.9545538485424192, 'k_m7ck_t1': 0.8296464394365108, 'k_m7ck_t2': 0.9557006848605157, 'n_m7ck_t': 1.9030935333077457, 'k_m7ck_deg': 0.8921194369366966}

# %%
if False:
    import tellurium as te
    from tools.dirs import dir_model,dir_calib_output
    from tools.tools import run_model
    model = te.loadSBMLModel(dir_model)
    with open(dir_calib_output,'r') as file:
        inferred_params = json.load(file)
    inferred_params['n_m7ck_t']=2
    params = {**inferred_params,'Mg_e':8}
    results = run_model(model,params=params,target_keys=['nM7CK'])
    model.plot()
