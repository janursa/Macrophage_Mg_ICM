# %%
import os
import sys
main_dir = '/Users/matin/Downloads/testProjs/intracellular_M'
sys.path.insert(0,main_dir)
from tools import dirs
from tools.tools import calibrate
import json
from models.params import free_params_p, fixed_params
from data.observations import observations,packages
from models.models import Macrophage
# %load_ext autoreload
# %autoreload
dir_model = dirs.dir_model
target_package = 'P5'
free_params = free_params_p[target_package]
studies = {}
for study in packages[target_package]:
    studies[study] = observations[study]
print(free_params)
print(studies.keys())

model_obj = Macrophage(dir_model=dir_model)

def callback(xk, convergence):
    params = {**fixed_params}
    keys = list(free_params.keys())
    for ii in range(len(keys)):
        params[keys[ii]] = xk[ii]
    error = model_obj.run(params = params,studies=studies)
    if  error < 0.01:
        return True
    
class Strategies:
    best1bin = 'best1bin'
    rand1exp = 'rand1exp'
inferred_params = calibrate(model = model_obj,fixed_params = fixed_params, free_params=free_params, studies = studies, n_proc=1,disp=True,max_iters=100,strategy=Strategies.best1bin,callback=callback)
with open(os.path.join(dirs.dir_outputs,'inferred_params_{}.json'.format(target_package)),'w') as f:
    f.write(json.dumps(inferred_params,indent=4))
os.system('say "Hey Matin, calibration is done, come back"')
# Out:
# {'IL8': [0.01, 10], 'k_il8_p': [0.01, 10], 'k_il8_d': [0.001, 1], 'k_il8_b': [0.001, 1], 'k_il8_ub': [0.001, 1], 'k_il8r_p': [0.001, 1], 'k_il8r_d': [0.001, 1], 'kd_ifngr_p1': [0.001, 10], 'n_ifngr_p1': [0.1, 10]}
# dict_keys(['eq_IL8', 'M18'])
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-a828408ce67a> in <module>
#      34     best1bin = 'best1bin'
#      35     rand1exp = 'rand1exp'
# ---> 36 inferred_params = calibrate(model = model_obj,fixed_params = fixed_params, free_params=free_params, studies = studies, n_proc=1,disp=True,max_iters=100,strategy=Strategies.best1bin,callback=callback)
#      37 with open(os.path.join(dirs.dir_outputs,'inferred_params_{}.json'.format(target_package)),'w') as f:
#      38     f.write(json.dumps(inferred_params,indent=4))
#
# ~/Downloads/testProjs/intracellular_M/tools/tools.py in calibrate(model, fixed_params, free_params, studies, max_iters, n_proc, disp, strategy, tol, callback)
#      71     calib_obj = Calibration_class(model,fixed_params,free_params,studies)
#      72
# ---> 73     inferred_params,error = calib_obj.optimize(n_proc=n_proc,max_iters=max_iters,disp=disp,strategy=strategy,tol=tol,callback=callback)
#      74     return inferred_params
#      75
#
# ~/Downloads/testProjs/intracellular_M/tools/tools.py in optimize(self, n_proc, max_iters, disp, strategy, tol, callback)
#      61     def optimize(self,n_proc,max_iters,disp,strategy,tol,callback):
#      62         results = differential_evolution(func = self.cost_function,bounds=list(self.free_params.values()),maxiter=max_iters,workers=n_proc,strategy=strategy,
# ---> 63             disp=disp,tol=tol,callback=callback)
#      64
#      65         inferred_params = {}
#
# ~/miniconda3/envs/v37_conda/lib/python3.7/site-packages/scipy/optimize/_differentialevolution.py in differential_evolution(func, bounds, args, strategy, maxiter, popsize, tol, mutation, recombination, seed, callback, disp, polish, init, atol, updating, workers, constraints)
#     306                                      workers=workers,
#     307                                      constraints=constraints) as solver:
# --> 308         ret = solver.solve()
#     309
#     310     return ret
#
# ~/miniconda3/envs/v37_conda/lib/python3.7/site-packages/scipy/optimize/_differentialevolution.py in solve(self)
#     757             # evolve the population by a generation
#     758             try:
# --> 759                 next(self)
#     760             except StopIteration:
#     761                 warning_flag = True
#
# ~/miniconda3/envs/v37_conda/lib/python3.7/site-packages/scipy/optimize/_differentialevolution.py in __next__(self)
#    1073                     feasible = True
#    1074                     cv = np.atleast_2d([0.])
# -> 1075                     energy = self.func(parameters)
#    1076                     self._nfev += 1
#    1077
#
# ~/miniconda3/envs/v37_conda/lib/python3.7/site-packages/scipy/optimize/_differentialevolution.py in __call__(self, x)
#    1259
#    1260     def __call__(self, x):
# -> 1261         return self.f(x, *self.args)
#    1262
#    1263
#
# ~/Downloads/testProjs/intracellular_M/tools/tools.py in cost_function(self, calib_params_values)
#      55             calib_params[key] = value
#      56         params = {**calib_params,**self.fixed_params}
# ---> 57         error = self.model.run(params=params,studies=self.studies)
#      58
#      59         return error
#
# ~/Downloads/testProjs/intracellular_M/models/models.py in run(self, params, studies)
#     175       flag = 1
#     176       try:
# --> 177         sims = self.simulate_studies(params,studies)
#     178       except tools.InvalidParams:
#     179         mean_cost = 1+random.random()
#
# ~/Downloads/testProjs/intracellular_M/models/models.py in simulate_studies(self, params, studies)
#      23         for study_tag,study_item in studies.items():
#      24             try:
# ---> 25               results = self.simulate_study(study_tag=study_tag,study=study_item,params=params)
#      26             except tools.InvalidParams:
#      27               raise tools.InvalidParams()
#
# ~/Downloads/testProjs/intracellular_M/models/models.py in simulate_study(self, study_tag, study, params)
#      40             inputs = study[ID]['inputs']
#      41             try:
# ---> 42               ID_results = self.simulate(study_tag = study_tag,params=params,inputs=inputs,measurement_scheme=measurement_scheme,experiment_period=experiment_period)
#      43             except tools.InvalidParams:
#      44               raise tools.InvalidParams()
#
# ~/Downloads/testProjs/intracellular_M/models/models.py in simulate(self, study_tag, params, inputs, measurement_scheme, experiment_period)
#     161       params = {**params,**inputs}
#     162       try:
# --> 163         results_raw = tools.run_model(model=self.model,params = params,duration=experiment_period+1,target_keys=target_keys,study=study_tag)
#     164       except tools.InvalidParams:
#     165         raise tools.InvalidParams()
#
# ~/Downloads/testProjs/intracellular_M/tools/tools.py in run_model(model, params, target_keys, duration, study)
#     121                 raise InvalidParams('run model didnt converge')
#     122     else:
# --> 123         results = model.simulate(start = 0,end = duration,steps = int(duration/2) ,selections = ['TIME']+target_keys)
#     124
#     125     return results
#
# ~/miniconda3/envs/v37_conda/lib/python3.7/site-packages/roadrunner/roadrunner.py in simulate(self, start, end, points, selections, output_file, steps)
#    3936             o.steps = steps
#    3937
# -> 3938         result = self._simulate(o)
#    3939
#    3940     #Check to make sure we made it to the 'end'.
#
# ~/miniconda3/envs/v37_conda/lib/python3.7/site-packages/roadrunner/roadrunner.py in _simulate(self, opt)
#    3605
#    3606     def _simulate(self, opt):
# -> 3607         return _roadrunner.RoadRunner__simulate(self, opt)
#    3608
#    3609     def _getValue(self, *args):
#
# KeyboardInterrupt:

# %%
print(inferred_params)
